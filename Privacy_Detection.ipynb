# %%
from fastai.vision import *

# %%
classes = ["Credit Cards", "Finger Prints", "Non-Private"]
file= ["Credit Cards.txt", "Finger Prints.txt", "Non-Private.txt"]

# %%
for i in range(len(classes)):
  temp = classes[i]
  temp2 = file[i]
  path = Path('data/private')
  dest = path/temp
  dest.mkdir(parents = True, exist_ok= True)
  download_images(path/temp2, dest, max_pics=20, max_workers=0)

# %%
path.ls()
# Out:
# [PosixPath('data/private/Non-Private'),
#  PosixPath('data/private/Finger Prints'),
#  PosixPath('data/private/Credit Cards')]

# %%
for c in classes:
  print(c)
  verify_images(path/c, delete = True, max_size =1000)
# Out:
# Credit Cards
# Finger Prints
# Non-Private

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train =".", valid_pct=0.2,
                                  ds_tfms = get_transforms(), size = 224,
                                  num_workers=4, bs =12).normalize(imagenet_stats)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
data.classes
# Out:
# ['Credit Cards', 'Finger Prints', 'Non-Private']

# %%
data.show_batch(rows=3, figsize=(7,8))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['Credit Cards', 'Finger Prints', 'Non-Private'], 3, 48, 12)

# %% [markdown]
# # Train Model

# %%
learn= cnn_learner(data, models.resnet34, metrics=  error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.862773</td>
#       <td>1.760670</td>
#       <td>0.416667</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.205517</td>
#       <td>1.396067</td>
#       <td>0.333333</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.816548</td>
#       <td>0.903579</td>
#       <td>0.166667</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.664624</td>
#       <td>0.665011</td>
#       <td>0.166667</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14' class='' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       56.00% [14/25 04:13<03:19]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-05, 1e-04))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.272087</td>
#       <td>0.179883</td>
#       <td>0.083333</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.146935</td>
#       <td>0.094206</td>
#       <td>0.000000</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
learn.save('stage-2')

# %% [markdown]
# #Interpretation

# %%
learn.load('stage-2')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# # Clearning Mislabelled data

# %%
from fastai. widgets import *

# %%
db = (ImageList.from_folder(path).split_none().
      label_from_folder().transform(get_transforms(), size= 224).
      databunch())
# Out:
# You can deactivate this warning by passing `no_check=True`.
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# ...

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics = error_rate)

learn_cln.load('stage-2')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# Learner(data=ImageDataBunch;
#
# Train: LabelList (60 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Non-Private,Non-Private,Non-Private,Non-Private,Non-Private
# Path: data/private;
#
# Valid: LabelList (0 items)
# x: ImageList
#
# y: CategoryList
#
# Path: data/private;
#
# Test: None, model=Sequential(
#   (0): Sequential(
# ...

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
ImageCleaner(ds,idxs, path)
# Out:
# 'No images to show :)'

# %%
ds, idxs = DatasetFormatter().from_similars(learn_cln)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:10<00:00]
#     </div>
# ...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# # Re-training the model after data cleaning

# %%
data = ImageDataBunch.from_csv(path, folder=".", valid_pct=0.2,csv_labels='cleaned.csv',
                               ds_tfms = get_transforms(), size =224, 
                               num_workers = 4, bs=12).normalize(imagenet_stats)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
learn =cnn_learner(data, models.resnet34, metrics =error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.553119</td>
#       <td>1.693991</td>
#       <td>0.416667</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.091812</td>
#       <td>0.203508</td>
#       <td>0.166667</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.737659</td>
#       <td>0.075042</td>
#       <td>0.000000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.537535</td>
#       <td>0.078705</td>
#       <td>0.000000</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
learn.save('stage-1')

# %% [markdown]
# Since the validation error is 0, we won't train the model with a smaller learning rate.
#
# Note: The validation error is 0, since the validation set has only 12 images and it is not sufficient to calculate the model accurately

# %%
learn.export()

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'Background.jpg')
img
# Out:
# Image (3, 1080, 1500)

# %%
learn = load_learner(path)

# %%
pred_class, pred_idx, outputs = learn.predict(img)
pred_class.obj
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# 'Non-Private'
